# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
confMatrix=np.zeros((17,17));
with open('/Users/ziegler/confmatrix.csv','r') as infile:
    csvfile=csv.reader(infile)
    for i,r in enumerate(csvfile):
        confMatrix[i,:]=np.int64(r)
print(confMatrix)
# Out:
# [[54.  8.  0.  0. 11.  3.  6.  2.  0.  1.  7.  7.  1.  0.  0.  0.  0.]
#  [34. 21.  5.  3. 11.  5.  3.  1.  1.  0.  5.  5.  2.  2.  1.  0.  1.]
#  [12. 12. 11. 12.  5.  2.  2.  8.  7.  3.  0.  3.  1.  6.  4.  5.  7.]
#  [14. 14. 18. 12.  2.  1.  2.  7.  7.  8.  1.  0.  2.  2.  2.  6.  2.]
#  [ 9.  5.  0.  0. 47. 17.  5.  0.  0.  0. 14.  3.  0.  0.  0.  0.  0.]
#  [20.  5.  0.  1. 25. 19.  7.  0.  1.  0. 11. 11.  0.  0.  0.  0.  0.]
#  [13.  1.  1.  0. 23.  9. 43.  1.  1.  0.  4.  4.  0.  0.  0.  0.  0.]
#  [15.  5. 12.  7.  1.  6.  6. 13. 13.  2.  2.  2.  1.  5.  4.  3.  3.]
#  [ 2.  3.  3.  2.  1.  0.  2.  0. 65.  0.  0.  1.  2. 19.  0.  0.  0.]
#  [ 6. 11. 10.  6.  1.  0.  2. 17.  1. 12.  0.  6.  7.  3.  6.  7.  5.]
#  [20.  3.  4.  0. 26. 13.  4.  0.  0.  0. 22.  8.  0.  0.  0.  0.  0.]
#  [24.  9.  2.  1.  3. 14.  9.  0.  0.  0. 12. 26.  0.  0.  0.  0.  0.]
#  [11.  9. 17. 14.  3.  6.  2.  9.  9.  3.  0.  1.  7.  3.  3.  1.  2.]
#  [ 9.  4. 14.  9.  1.  1.  2.  8. 20.  1.  1.  0.  2. 25.  1.  2.  0.]
#  [ 6. 15. 12.  7.  0.  0.  4.  9.  0.  3.  0.  1.  4.  0. 23. 13.  3.]
#  [ 8.  6. 15.  9.  0.  2.  2.  6.  0.  5.  1.  3.  7.  3. 15. 16.  2.]
#  [16.  8. 11.  8.  1.  3.  7.  8.  2.  7.  1.  0.  4.  2.  7.  6.  9.]]

# %%
matrix=np.int32(confMatrix)
colorMatrix=np.zeros(matrix.shape)
for i in range(matrix.shape[0]):
    colorMatrix[i,:]=np.round(matrix[i,:]/sum(matrix[i,:]),2)
print(matrix)
# Out:
# [[54  8  0  0 11  3  6  2  0  1  7  7  1  0  0  0  0]
#  [34 21  5  3 11  5  3  1  1  0  5  5  2  2  1  0  1]
#  [12 12 11 12  5  2  2  8  7  3  0  3  1  6  4  5  7]
#  [14 14 18 12  2  1  2  7  7  8  1  0  2  2  2  6  2]
#  [ 9  5  0  0 47 17  5  0  0  0 14  3  0  0  0  0  0]
#  [20  5  0  1 25 19  7  0  1  0 11 11  0  0  0  0  0]
#  [13  1  1  0 23  9 43  1  1  0  4  4  0  0  0  0  0]
#  [15  5 12  7  1  6  6 13 13  2  2  2  1  5  4  3  3]
#  [ 2  3  3  2  1  0  2  0 65  0  0  1  2 19  0  0  0]
#  [ 6 11 10  6  1  0  2 17  1 12  0  6  7  3  6  7  5]
#  [20  3  4  0 26 13  4  0  0  0 22  8  0  0  0  0  0]
#  [24  9  2  1  3 14  9  0  0  0 12 26  0  0  0  0  0]
#  [11  9 17 14  3  6  2  9  9  3  0  1  7  3  3  1  2]
#  [ 9  4 14  9  1  1  2  8 20  1  1  0  2 25  1  2  0]
#  [ 6 15 12  7  0  0  4  9  0  3  0  1  4  0 23 13  3]
#  [ 8  6 15  9  0  2  2  6  0  5  1  3  7  3 15 16  2]
#  [16  8 11  8  1  3  7  8  2  7  1  0  4  2  7  6  9]]

# %%
plt.figure(figsize=(8,8))
plt.imshow(colorMatrix,cmap='gray')
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        plt.text(i,j,matrix[j,i],ha='center',va='center',color='r',size=12)
        
plt.xticks(ticks=np.arange(0,matrix.shape[1],1),labels=np.arange(1,matrix.shape[1]+1,1))
plt.yticks(ticks=np.arange(0,matrix.shape[0],1),labels=np.arange(1,matrix.shape[0]+1,1))
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.title('Confusion Matrix')
plt.savefig('/Users/ziegler/classes/ee552/project2/plots/confMatrixWallFisherTest.png')

plt.figure(figsize=(8,8))
plt.imshow(colorMatrix,cmap='gray')
for i in range(matrix.shape[0]):
    for j in range(matrix.shape[1]):
        plt.text(i,j,colorMatrix[j,i],ha='center',va='center',color='r',size=9)
        
plt.xticks(ticks=np.arange(0,matrix.shape[1],1),labels=np.arange(1,matrix.shape[1]+1,1))
plt.yticks(ticks=np.arange(0,matrix.shape[0],1),labels=np.arange(1,matrix.shape[0]+1,1))
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.title('Classification Matrix')
plt.savefig('/Users/ziegler/classes/ee552/project2/plots/classMatrixWallFisherTest.png')
