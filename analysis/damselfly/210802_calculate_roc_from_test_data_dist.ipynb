# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import torch
import h5py
import os
import sys
import scipy
import damselfly as df
import scipy.signal
import scipy.integrate

PATH = '/storage/home/adz6/group/project'
RESULTPATH = os.path.join(PATH, 'results/damselfly')
PLOTPATH = os.path.join(PATH, 'plots/damselfly')
DATAPATH = os.path.join(PATH, 'damselfly/data/datasets')
SIMDATAPATH = os.path.join(PATH, 'damselfly/data/sim_data')

"""
Date: 6/25/2021
Description: template
"""

# %%
os.listdir(os.path.join(RESULTPATH, 'roc'))

# %%
#file1 = '210802_roc_210730_84_1d2sl3mt.npy'
file = '211015_roc_211015_84_1d2sl4mt_partial_spec.npy'
#file = '210802_roc_210730_84_1d2sl5mt.npy'
#file = '210802_roc_210730_84_1d2sl6mt.npy'

file_list = [file]
#file_list = [file4]

file4 = '211018_analytical_mf_roc_df84_mt4_mismatch1.0.npz'
file5 = '211018_analytical_mf_roc_df84_mt4_mismatch0.9.npz'
file6 = '211018_analytical_mf_roc_df84_mt4_mismatch0.8.npz'
file7 = '211018_analytical_mf_roc_df84_mt4_mismatch0.7.npz'
file8 = '211018_analytical_mf_roc_df84_mt4_mismatch0.6.npz'
mf_file_list = [file4, file5, file6, file7, file8]

# %%
sns.set_theme(style='whitegrid', context='poster')
plt.figure(figsize=(13, 8))
match = [1.0, 0.9, 0.8, 0.7, 0.6, ]
for n, filename in enumerate(file_list):

    print(n)
    test_output = np.load(os.path.join(RESULTPATH, 'roc', filename))
    noise_output = test_output[np.argwhere(test_output[:, 0] == 0).squeeze(), :]
    signal_output = test_output[np.argwhere(test_output[:, 0] == 1).squeeze(), :]
    
    TPR_array = np.zeros(1801)
    FPR_array = np.zeros(1801)
    for i, T in enumerate(np.linspace(0, 1, 1801)):

        TP = np.argwhere(signal_output[:, 2] >= T).squeeze().size
        FP = np.argwhere(noise_output[:, 2] >= T).squeeze().size

        TPR = TP / signal_output[:, 0].size
        FPR = FP / noise_output[:, 0].size

        TPR_array[i] = TPR
        FPR_array[i] = FPR

    
    #plt.plot(FPR_array, TPR_array, label=f'CNN, AUC={-1 * np.round(scipy.integrate.trapezoid(TPR_array, FPR_array), 4)}', )
    plt.plot(FPR_array, TPR_array, label=f'CNN' )
labels = ['Template Length = Signal Length', 'Template Length = 16384']


for n, filename in enumerate(mf_file_list):

    test_output = np.load(os.path.join(RESULTPATH, 'roc', filename))
    #print(test_output.shape)
    #noise_output = test_output[np.argwhere(test_output[:, 0] == 0).squeeze(), :]
    #signal_output = test_output[np.argwhere(test_output[:, 0] == 1).squeeze(), :]
    
    TPR_array = np.zeros(201)
    FPR_array = np.zeros(201)
    for i, T in enumerate(np.linspace(0, 1, 201)):

        TP = np.argwhere(signal_output[:, 2] >= T).squeeze().size
        FP = np.argwhere(noise_output[:, 2] >= T).squeeze().size

        TPR = TP / signal_output[:, 0].size
        FPR = FP / noise_output[:, 0].size

        TPR_array[i] = TPR
        FPR_array[i] = FPR

    #plt.plot(test_output['fpr'], test_output['tpr'], label=f'MF, AUC={-1 * np.round(scipy.integrate.trapezoid(test_output["tpr"],test_output["fpr"]), 4)}')
    plt.plot(test_output['fpr'], test_output['tpr'], label=f'MF, Mean Match={match[n]}')

    
#plt.plot(np.linspace(0,1,100), np.linspace(0,1,100), '--',color='grey')
plt.legend(loc=4)

plt.xlabel('FPR')
plt.ylabel('TPR')

#plt.title('ROC Curve CNN vs Matched Filter')
#plt.tight_layout()
#plt.xlim(-0.0001, 0.001)
#plt.yscale('log')
plt.xscale('log')
plt.ylim(0.8, 1.05)
plt.xlim(1e-8, 1e0)
plt.savefig(os.path.join(PLOTPATH, '211018_ROC_cnn_vs_8192mf_ideal_match.png'))

# %%
print(np.argmin(abs(FPR_array - 0.001)))
print(np.argmin(abs(test_output['fpr'] - 0.001)))
print(TPR_array[784], test_output['tpr'][56])

# %%
for filename in mf_file_list:

    test_output = np.load(os.path.join(RESULTPATH, 'roc', filename))
    print(test_output.shape)
    #noise_output = test_output[np.argwhere(test_output[:, 0] == 0).squeeze(), :]
    #signal_output = test_output[np.argwhere(test_output[:, 0] == 1).squeeze(), :]
    
    #TPR_array = np.zeros(201)
    #FPR_array = np.zeros(201)
    #for i, T in enumerate(np.linspace(0, 1, 201)):

    #    TP = np.argwhere(signal_output[:, 2] >= T).squeeze().size
    #    FP = np.argwhere(noise_output[:, 2] >= T).squeeze().size

    #    TPR = TP / signal_output[:, 0].size
    #    FPR = FP / noise_output[:, 0].size

    #    TPR_array[i] = TPR
    #    FPR_array[i] = FPR

    plt.plot(test_output[0], test_output[1])

# %%
noise_output = test_output[np.argwhere(test_output[:, 0] == 0).squeeze(), :]
signal_output = test_output[np.argwhere(test_output[:, 0] == 1).squeeze(), :]

# %%
hist11 = plt.hist(signal_output[:, 2], 64, histtype='step')
#hist10 = plt.hist(signal_output[:, 1], 64, histtype='step')

hist01 = plt.hist(noise_output[:, 2], 64, histtype='step')
#hist00 = plt.hist(noise_output[:, 1], 64, histtype='step')

# %%
TPR_array = np.zeros(201)
FPR_array = np.zeros(201)
for i, T in enumerate(np.linspace(0, 1, 201)):
    
    TP = np.argwhere(signal_output[:, 2] >= T).squeeze().size
    FP = np.argwhere(noise_output[:, 2] >= T).squeeze().size
    
    TPR = TP / signal_output[:, 0].size
    FPR = FP / noise_output[:, 0].size
    
    TPR_array[i] = TPR
    FPR_array[i] = FPR
    
plt.plot(FPR_array, TPR_array)

# %%
TPR_array = np.zeros(201)
FPR_array = np.zeros(201)
for i, T in enumerate(np.linspace(0, 1, 201)):
    
    TP = np.argwhere(noise_output[:, 1] >= T).squeeze().size
    FP = np.argwhere(signal_output[:, 1] >= T).squeeze().size
    
    TPR = TP / noise_output[:, 0].size
    FPR = FP / signal_output[:, 0].size
    
    TPR_array[i] = TPR
    FPR_array[i] = FPR
    
plt.plot(FPR_array, TPR_array)

# %%
hist1 = plt.hist(test_output[:, 2], 64, histtype='step')
hist0 = plt.hist(test_output[:, 1], 64, histtype='step')

# %%
def GetTrackLength(rng, slicesize, mean=3, signal_length=8192 ):
    est_track_length = int(slicesize * rng.exponential(mean))
    if est_track_length >= signal_length:
        return signal_length
    else:
        return est_track_length
    
def noise(rng, var, size, shape):
    noise = rng.multivariate_normal([0,0], np.eye(2) * var / 2, size)
    noise = noise[:, 0] + 1j * noise[:, 1]
    
    return noise.reshape(shape)

dataset_file = '210730_84_1d2sl_eval.h5'
h5datafile = h5py.File(os.path.join(SIMDATAPATH, dataset_file), 'r')

var = 1.38e-23 * 10 * 50 * 200e6

signals = h5datafile['data'][:]

noise_samples = 1
#shape = signals.shape
#size = signals.size

track_lengths = np.arange(512, 2*8192 + 512, 512)
ntrack = track_lengths.size

nsignals = signals.shape[0]

noise_scores = np.zeros((ntrack, noise_samples, nsignals, nsignals))
signal_scores = np.zeros((ntrack, noise_samples, nsignals, nsignals))

for i, track_len in enumerate(track_lengths):
    for n in range(noise_samples):
        print(track_len)
        aug_signals = np.zeros((signals.shape[0], track_len), dtype=np.complex64) 
            
        aug_signals = signals[:, 0:track_len]
        
        norm = 1 / np.sqrt(var * np.diag(np.matmul(aug_signals, aug_signals.conjugate().T)))
        
        #print(norm.shape, aug_signals.shape, templates.shape)
        
        templates = aug_signals * norm.reshape((norm.size, 1)).repeat(track_len, axis=-1)
        
        noisy_data = aug_signals + noise(rng, var, aug_signals.size, aug_signals.shape)

        #x = abs(scipy.signal.fftconvolve(noisy_data, templates, axes=-1, mode='valid'))
        x = abs(np.matmul(noisy_data, templates.conjugate().T))
        signal_scores[i, n, :] = x

    
        x = abs(np.matmul(noise(rng, var, templates.size, templates.shape), templates.conjugate().T))
        #x = abs(np.matmul(noise(rng, var, size, shape)[:,0:template_size], templates.conjugate().T))
        #print(np.max(x, axis=-1), np.mean(x))
        #print(x)
        noise_scores[i, n, :] = x
        
        #if i % 5 == 4:
        #    print(f'{i + 1} / {ntrack * noise_samples}')

result_name = '210731_matched_filter_scores_variable_track_length_10K.npz'

np.savez(os.path.join(RESULTPATH, result_name), signal=signal_scores, noise=noise_scores, track_lengths=track_lengths, noise_samp=noise_samples)

# %%
for item in h5datafile['meta']:
    print(item)

# %%
metadata = {}
for n, dset in enumerate(h5datafile['meta']):
    metadata[dset] = h5datafile['meta'][dset][:]
    
metadata = pd.DataFrame(metadata)

# %%
template_size = 8192

norm = 1 / np.sqrt(var * np.diag(np.matmul(signals[:, 0:template_size], signals[:, 0:template_size].conjugate().T)))

templates = signals[:, 0:template_size] * norm.reshape((norm.size, 1)).repeat(template_size, axis=-1)

# %%
print(abs(np.vdot(templates[0, :], signals[0, 0:template_size])))
print(np.max(abs(scipy.signal.fftconvolve(templates[0, :], signals[0, :], mode='valid'))))

track_len = 4096
aug_signal = np.zeros(signals[0, :].shape, dtype=np.complex64) 

aug_signal[0:track_len] = signals[0, 0:track_len]

print(np.max(abs(scipy.signal.fftconvolve(templates[0, :], aug_signal, mode='valid'))))

# %%
rng = np.random.default_rng()
slicesize = 8192
ntrack = 1000
mean_length = 3
track_lengths = np.zeros(ntrack, dtype=np.int32)

for n in range(ntrack):
    track_lengths[n] = GetTrackLength(rng, slicesize, mean=mean_length, signal_length=signals.shape[-1])

# %%
plt.hist(track_lengths, 32)

# %%
noise_samples = 5
#shape = signals.shape
#size = signals.size

track_lengths = np.arange(512, 2*8192 + 512, 512)
ntrack = track_lengths.size

nsignals = signals.shape[0]

noise_scores = np.zeros((ntrack * noise_samples, nsignals, nsignals))
signal_scores = np.zeros((ntrack * noise_samples, nsignals, nsignals))

for i, track_len in enumerate(track_lengths):
    for n in range(noise_samples):
        print(track_len)
        aug_signals = np.zeros((signals.shape[0], track_len), dtype=np.complex64) 
            
        aug_signals = signals[:, 0:track_len]
        
        norm = 1 / np.sqrt(var * np.diag(np.matmul(aug_signals, aug_signals.conjugate().T)))
        
        #print(norm.shape, aug_signals.shape, templates.shape)
        
        templates = aug_signals * norm.reshape((norm.size, 1)).repeat(track_len, axis=-1)
        
        noisy_data = aug_signals + noise(rng, var, aug_signals.size, aug_signals.shape)

        #x = abs(scipy.signal.fftconvolve(noisy_data, templates, axes=-1, mode='valid'))
        x = abs(np.matmul(noisy_data, templates.conjugate().T))
        print(x)
        signal_scores[i, :] = x

    
        x = abs(np.matmul(noise(rng, var, templates.size, templates.shape), templates.conjugate().T))
        #x = abs(np.matmul(noise(rng, var, size, shape)[:,0:template_size], templates.conjugate().T))
        #print(np.max(x, axis=-1), np.mean(x))
        print(x)
        noise_scores[i, :] = x
        
        if i % 10 == 9:
            print(f'{i + 1} / {ntrack}')

result_name = '210731_matched_filter_scores_mt3_10K.npz'

np.savez(os.path.join(RESULTPATH, result_name), signal=signal_scores, noise=noise_scores, track_len=track_lengths)

# %%
print(track_lengths)
